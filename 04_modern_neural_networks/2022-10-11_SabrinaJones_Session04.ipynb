# %% [markdown]
# # Iteration VS. Loss

# %% [markdown]
# ![Iteration%20vs%20Loss.png](attachment:Iteration%20vs%20Loss.png)

# %% [markdown]
# # Iteration VS. Accuracy

# %% [markdown]
# ![Iteration%20vs%20Accuracy.png](attachment:Iteration%20vs%20Accuracy.png)
